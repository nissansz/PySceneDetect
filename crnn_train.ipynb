# %% [markdown]
# <a href="https://colab.research.google.com/github/nissansz/PySceneDetect/blob/master/crnn_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/crnn.zip' #解压到根目录
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/crnn.zip
#    creating: crnn/
#    creating: crnn/.idea/
#   inflating: crnn/.idea/.gitignore
#   inflating: crnn/.idea/CRNN.iml
#    creating: crnn/.idea/inspectionProfiles/
#   inflating: crnn/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: crnn/.idea/inspectionProfiles/Project_Default.xml
#   inflating: crnn/.idea/misc.xml
#   inflating: crnn/.idea/modules.xml
#   inflating: crnn/.idea/workspace.xml
#   inflating: crnn/config.py
#   inflating: crnn/crnn.py
#    creating: crnn/data/
#   inflating: crnn/data/chinese -jpep1.txt
#   inflating: crnn/data/chinese-all - 副本.txt
#   inflating: crnn/data/chinese-lines python getChinese缺少半角 和全角空格.txt
#   inflating: crnn/data/chinese-lines-all.txt
#   inflating: crnn/data/chinese-lines.txt
#   inflating: crnn/data/chinese.txt
#    creating: crnn/data/images/
#    creating: crnn/data/images/val/
# ...

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/crnnTraintext.zip' #解压到根目录
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/crnnTraintext.zip
#    creating: crnnTraintext/
#    creating: crnnTraintext/.idea/
#   inflating: crnnTraintext/.idea/.gitignore
#   inflating: crnnTraintext/.idea/CRNN.iml
#    creating: crnnTraintext/.idea/inspectionProfiles/
#   inflating: crnnTraintext/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: crnnTraintext/.idea/inspectionProfiles/Project_Default.xml
#   inflating: crnnTraintext/.idea/misc.xml
#   inflating: crnnTraintext/.idea/modules.xml
#   inflating: crnnTraintext/.idea/workspace.xml
#   inflating: crnnTraintext/config.py
#   inflating: crnnTraintext/crnn.py
#    creating: crnnTraintext/data/
#   inflating: crnnTraintext/data/chinese -jpep1.txt
#   inflating: crnnTraintext/data/chinese-all - 副本.txt
#   inflating: crnnTraintext/data/chinese-lines python getChinese缺少半角 和全角空格.txt
#   inflating: crnnTraintext/data/chinese-lines-all.txt
#   inflating: crnnTraintext/data/chinese-lines.txt
# ...

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/labels 添加易错字符-1300万 20220223dramaSrt.zip' #解压到根目录
# !unzip '/content/drive/MyDrive/Colab Notebooks/bg 0-33张追新番无字幕截图.zip'  #解压到根目录
# !unzip '/content/drive/MyDrive/Colab Notebooks/trainkeys_shuffle - 1300万.zip' #解压到根目录
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/labels 添加易错字符-1300万 20220223dramaSrt.zip
#   inflating: val.txt
#   inflating: train.txt
# Archive:  /content/drive/MyDrive/Colab Notebooks/bg 0-33张追新番无字幕截图.zip
#    creating: bg/
#   inflating: bg/0.jpg
#   inflating: bg/1.jpg
#   inflating: bg/10.jpg
#   inflating: bg/11.jpg
#   inflating: bg/12.jpg
#   inflating: bg/13.jpg
#   inflating: bg/14.jpg
#   inflating: bg/15.jpg
#   inflating: bg/16.jpg
#   inflating: bg/17.jpg
#   inflating: bg/18.jpg
#   inflating: bg/19.jpg
#   inflating: bg/2.jpg
#   inflating: bg/20.jpg
#   inflating: bg/21.jpg
#   inflating: bg/22.jpg
#   inflating: bg/23.jpg
#   inflating: bg/24.jpg
#   inflating: bg/25.jpg
#   inflating: bg/26.jpg
#   inflating: bg/27.jpg
#   inflating: bg/28.jpg
#   inflating: bg/29.jpg
#   inflating: bg/3.jpg
#   inflating: bg/30.jpg
#   inflating: bg/31.jpg
#   inflating: bg/32.jpg
#   inflating: bg/33.jpg
#   inflating: bg/4.jpg
#   inflating: bg/5.jpg
#   inflating: bg/6.jpg
# ...

# %%
# !pip install fontTools
# Out:
# ...
#      |████████████████████████████████| 898 kB 4.1 MB/s
# ...

# %%
# !python /content/crnn/train.py --lr 0.00001 --chinese '/content/crnn/data/chinese.txt' --labels '/content/' --num_workers 2 --shufflePath '/content/trainkeys_shuffle.txt' --bgPath '/content/bg/' --weights '/content/drive/MyDrive/Colab Notebooks/chinese_247000_427398_01_1.0646029619215782_0.8785064837655844.pt' --batch_size 32 --savebatch 500 --shuffleLast 247000
# Out:
# python3: can't open file '/content/crnn/train.py': [Errno 2] No such file or directory

# %%
# !python /content/crnnTraintext/train.py --lr 0.00001 --chinese '/content/crnn/data/chinese.txt' --labels '/content/' --num_workers 2 --shufflePath '/content/trainkeys_shuffle.txt' --bgPath '/content/bg/' --weights '/content/drive/MyDrive/Colab Notebooks/chinese_247000_427398_01_1.0646029619215782_0.8785064837655844.pt' --batch_size 32 --savebatch 10 --shuffleLast 247000
# Out:
# load /content/drive/MyDrive/Colab Notebooks/chinese_247000_427398_01_1.0646029619215782_0.8785064837655844.pt model success!
# parameter: epochs=1,batch_size=32,lr=1e-05,device=cuda,chinese=/content/crnn/data/chinese.txt,labels/content/,imgH=32,nc=1,nh=256,val_epoch=1,save_all=True,best=0.5,test=False,weights=/content/drive/MyDrive/Colab Notebooks/chinese_247000_427398_01_1.0646029619215782_0.8785064837655844.pt,name=weights
# optimizer:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1e-05
#     weight_decay: 0
# )
# model:
# CRNN(
#   (cnn): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
# !/opt/bin/nvidia-smi
# Out:
# Sat Feb 19 22:16:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/chinese.zip'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: chinese/img_0838681.jpg
#   inflating: chinese/img_0025291.jpg
#   inflating: chinese/img_0356692.jpg
#   inflating: chinese/img_0302981.jpg
#   inflating: chinese/img_0215365.jpg
#   inflating: chinese/img_0665975.jpg
#   inflating: chinese/img_0465912.jpg
#   inflating: chinese/img_0960829.jpg
#   inflating: chinese/img_0603112.jpg
#   inflating: chinese/img_0425161.jpg
#   inflating: chinese/img_0544515.jpg
#   inflating: chinese/img_0050574.jpg
#   inflating: chinese/img_0584250.jpg
#   inflating: chinese/img_0649775.jpg
#   inflating: chinese/img_0358807.jpg
#   inflating: chinese/img_0073789.jpg
#   inflating: chinese/img_0057563.jpg
#   inflating: chinese/img_0634060.jpg
#   inflating: chinese/img_0538809.jpg
#   inflating: chinese/img_0374807.jpg
#   inflating: chinese/img_0047009.jpg
#   inflating: chinese/img_0231756.jpg
#   inflating: chinese/img_0677034.jpg
#   inflating: chinese/img_0497932.jpg
# ...

# %%
# !python /content/crnn/train.py
# Out:
# no saved model, training will start from scratch!
# parameter: epochs=1,batch_size=32,lr=0.0001,device=cuda,chinese=/content/crnn/data/chinese.txt,images=/content/chinese,labels/content/crnn/data/labels/,imgH=32,nc=1,nh=256,val_epoch=1,save_all=True,best=0.5,test=False,weights=,name=/content/drive/MyDrive/Colab Notebooks/weights
# optimizer:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# model:
# CRNN(
#   (cnn): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !ls '/content/chinese'

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/weights'

# %%
# !cp '/content/chinese' '/content/drive/MyDrive/Colab Notebooks/Chinese'
# Out:
# cp: -r not specified; omitting directory '/content/chinese'

# %% [markdown]
# 修改dataset.py, train.py 图片路径，weights删除

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/chinese.zip' '/content/drive/MyDrive/Colab Notebooks/chineseExtracted'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/chinese.zip
# caution: filename not matched:  /content/drive/MyDrive/Colab Notebooks/chineseExtracted

# %%
# !cp -r '/content/chinese' '/content/drive/MyDrive/Colab Notebooks/Chinese'
# Out:
# ^C

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/chinese.zip' '/crnn/chinese/'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/chinese.zip
# caution: filename not matched:  /crnn/chinese/

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !pip list #查看所有包。Pillow 是7.1.2

# %%
# !pip install Pillow==8.2.0

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/crnn/train.py'

# %%
# !cat /proc/meminfo #显示内存
import torch
print(torch.__version__) #显示torch版本
flag = torch.cuda.is_available()
print(flag)

ngpu= 1
# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(device)
print(torch.cuda.get_device_name(0))
print(torch.rand(3,3).cuda())

# %%
# !unrar e '/content/drive/MyDrive/Colab Notebooks/Chinese_dataset.rar'

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/Chinese_dataset.rar'  '/crnn/datachinese'

# %%
# !find '/content/drive/MyDrive/Colab Notebooks/' img_0437502.jpg
# Out:
# /content/drive/MyDrive/Colab Notebooks/
# /content/drive/MyDrive/Colab Notebooks/crnn3x1024.zip
# /content/drive/MyDrive/Colab Notebooks/.ipynb_checkpoints
# /content/drive/MyDrive/Colab Notebooks/Chinese_dataset.rar
# /content/drive/MyDrive/Colab Notebooks/crnn-train.ipynb
# img_0437502.jpg

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# Chinese_dataset.rar  crnn3x1024.zip  crnn-train.ipynb

# %%
# !ls /
# Out:
# bin	 crnn	  etc	lib32  mnt   python-apt  sbin  tensorflow-1.15.2  usr
# boot	 datalab  home	lib64  opt   root	 srv   tmp		  var
# content  dev	  lib	media  proc  run	 sys   tools

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# ls: cannot access '!ls': No such file or directory
# '/content/drive/MyDrive/Colab Notebooks/':
# Chinese      crnn3x1024.zip  crnnReadZip
# chinese.zip  crnn_original   crnn-train.ipynb

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/crnn_original/crnn'
# Out:
# crnn.py  detect.py    test     train_batch.py  utils   weights1
# data	 __pycache__  test.py  train.py        val.py

# %%
help()
# Out:
# Welcome to Python 3.7's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# No Python documentation found for 'edit'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# No Python documentation found for 'vm'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
# !unrar t '/crnn/datachinese'

# %%
# !unrar e '/crnn/datachinese'
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /crnn/datachinese
#
#
# Would you like to replace the existing file img_0994202.jpg
#   3291 bytes, modified on 2018-09-30 21:59
# with a new one
#   3291 bytes, modified on 2018-09-30 21:59
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit q
#
# Program aborted

# %%
# !unrar x '/crnn/datachinese' '/crnn/datachineseExtracted'
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /crnn/datachinese
#
# No files to extract

# %%
# !ls '/crnn/datachinese'
# Out:
# /crnn/datachinese

# %%
# !ls '/crnn/datachinese'
# Out:
# /crnn/datachinese
